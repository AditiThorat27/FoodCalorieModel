# %%
# --- STEP 1: CHECK GPU, LIBRARIES, AND AUTHENTICATE ---
print("Checking for GPU access and installing libraries...")
# !pip install ultralytics roboflow -q

from google.colab import drive
from ultralytics import YOLO
from roboflow import Roboflow
import torch
import os
import time

# 1. GPU Check
if torch.cuda.is_available():
    print(f"✅ GPU is available! Device: {torch.cuda.get_device_name(0)}")
else:
    # If the GPU is not back yet, we must wait.
    raise SystemExit("❌ GPU is NOT available. Please stop and try again later.")

# 2. Authenticate Roboflow and Mount Drive
print("\nMounting Google Drive and authenticating Roboflow...")
drive.mount('/content/drive', force_remount=True)

rf = Roboflow(api_key="9PkAjBQJU2ZBQ4GhX9tM")
project = rf.workspace("flens-mikns").project("food-detection-guwga")
version = project.version(2)
print("✅ Authentication and Drive mount complete.")
# Out:
# Checking for GPU access and installing libraries...
# ✅ GPU is available! Device: Tesla T4
#
# Mounting Google Drive and authenticating Roboflow...
# Mounted at /content/drive
# loading Roboflow workspace...
# loading Roboflow project...
# ✅ Authentication and Drive mount complete.

# %%
# --- FIND THE TRUE SHARED FOLDER PATH ---
import os

# Define the folder name we are looking for
SEARCH_FOLDER = 'ML_Food_Project'
print(f"Searching for the shared folder: {SEARCH_FOLDER}...")

# Use a shell command to recursively find the folder
# !find /content/drive/ -type d -name {SEARCH_FOLDER}

print("\n--- Please copy the output path above and use it in Step 2. ---")
# Out:
# Searching for the shared folder: ML_Food_Project...
#
# --- Please copy the output path above and use it in Step 2. ---

# %%
# --- STEP 1: CHECK GPU, LIBRARIES, AND AUTHENTICATE ---
print("Checking for GPU access and installing libraries...")
# !pip install ultralytics roboflow -q

from google.colab import drive
from ultralytics import YOLO
from roboflow import Roboflow
import torch
import os
import time

# 1. GPU Check
if torch.cuda.is_available():
    print(f"✅ GPU is available! Device: {torch.cuda.get_device_name(0)}")
else:
    raise SystemExit("❌ GPU is NOT available. Please stop and try again later.")

# 2. Authenticate Roboflow and Mount Drive (Already done, but needed for variable definition)
print("\nMounting Google Drive and authenticating Roboflow...")
drive.mount('/content/drive', force_remount=True)

rf = Roboflow(api_key="9PkAjBQJU2ZBQ4GhX9tM")
project = rf.workspace("flens-mikns").project("food-detection-guwga")
version = project.version(2)
print("✅ Authentication and Drive mount complete.")
# Out:
# Checking for GPU access and installing libraries...
# ✅ GPU is available! Device: Tesla T4
#
# Mounting Google Drive and authenticating Roboflow...
# Mounted at /content/drive
# loading Roboflow workspace...
# loading Roboflow project...
# ✅ Authentication and Drive mount complete.

# %%
# --- STEP 1: CHECK GPU, LIBRARIES, AND AUTHENTICATE ---
print("Checking for GPU access and installing libraries...")
# !pip install ultralytics roboflow -q

from google.colab import drive
from ultralytics import YOLO
from roboflow import Roboflow
import torch
import os
import time

# 1. GPU Check
if torch.cuda.is_available():
    print(f"✅ GPU is available! Device: {torch.cuda.get_device_name(0)}")
else:
    raise SystemExit("❌ GPU is NOT available. Please stop and try again later.")

# 2. Authenticate Roboflow and Mount Drive
print("\nMounting Google Drive and authenticating Roboflow...")
drive.mount('/content/drive', force_remount=True)

rf = Roboflow(api_key="9PkAjBQJU2ZBQ4GhX9tM")
project = rf.workspace("flens-mikns").project("food-detection-guwga")
version = project.version(2)
print("✅ Authentication and Drive mount complete.")
# Out:
# Checking for GPU access and installing libraries...
# ✅ GPU is available! Device: Tesla T4
#
# Mounting Google Drive and authenticating Roboflow...
# Mounted at /content/drive
# loading Roboflow workspace...
# loading Roboflow project...
# ✅ Authentication and Drive mount complete.

# %%
# --- STEP 1: CHECK GPU, LIBRARIES, AND AUTHENTICATE ---
print("Checking for GPU access and installing libraries...")
# !pip install ultralytics roboflow -q

from google.colab import drive
from ultralytics import YOLO
from roboflow import Roboflow
import torch
import os
import time

# 1. GPU Check
if torch.cuda.is_available():
    print(f"✅ GPU is available! Device: {torch.cuda.get_device_name(0)}")
else:
    raise SystemExit("❌ GPU is NOT available. Please stop and try again later.")

# 2. Authenticate Roboflow and Mount Drive
print("\nMounting Google Drive and authenticating Roboflow...")
drive.mount('/content/drive', force_remount=True)

rf = Roboflow(api_key="9PkAjBQJU2ZBQ4GhX9tM")
project = rf.workspace("flens-mikns").project("food-detection-guwga")
version = project.version(2)
print("✅ Authentication and Drive mount complete.")
# Out:
# Checking for GPU access and installing libraries...
# ✅ GPU is available! Device: Tesla T4
#
# Mounting Google Drive and authenticating Roboflow...
# Mounted at /content/drive
# loading Roboflow workspace...
# loading Roboflow project...
# ✅ Authentication and Drive mount complete.

# %%
# --- STEP 2: LAUNCH YOLOv8M-SEG (CLEAN START FROM EPOCH 15) ---
import os
from ultralytics import YOLO
import time

# Define all paths
DATA_PATH = '/content/Food-Detection-2'
# The checkpoint file exists at this shared location (READ ACCESS IS FINE):
CHECKPOINT_PATH = '/content/drive/MyDrive/ML_Food_Project/YOLO_Checkpoints/food_seg_v1_YOLOv8M_run_2/weights/last.pt'
TARGET_EPOCHS_TO_RUN = 36 # 50 (Total target) - 14 (Last completed epoch) = 36 new epochs.

# 1. Load the interrupted model from Drive
# We load the weights, but we will start a *new* training instance.
model = YOLO(CHECKPOINT_PATH)

# 2. Start a completely NEW training run with a unique name
# We set the 'epochs' argument to the number of *new* epochs we need to run (36).
print(f"\nStarting CLEAN training run (36 new epochs) to bypass permission error...")

results = model.train(
    data=f'{DATA_PATH}/data.yaml',
    task='segment',
    epochs=TARGET_EPOCHS_TO_RUN, # RUN ONLY THE REMAINING 36 EPOCHS
    imgsz=640,
    batch=16,

    # CRITICAL: We use a NEW NAME and a NEW PROJECT to ensure the save location is clean.
    name='food_seg_v1_YOLOv8M_CLEAN_START',
    project='/content/drive/MyDrive/YOLO_RESUME_OUTPUT', # SAFE SAVE LOCATION
    save_period=5
)

print(f"\n🎉 YOLOv8m Segmentation Training RESUMED. This run completes the job up to Epoch 50.")
# Out:
# Starting CLEAN training run (36 new epochs) to bypass permission error...
# Ultralytics 8.3.229 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# --- FINAL VALIDATION AND METRICS CHECK ---
import os
import shutil
from ultralytics import YOLO
from google.colab import drive
import torch
import time

# 1. Define Paths and Load Model
# The model was saved to this new, clean location to bypass permission errors:
FINAL_RUN_DIR = '/content/drive/MyDrive/YOLO_RESUME_OUTPUT/food_seg_v1_YOLOv8M_CLEAN_START2'
FINAL_WEIGHTS_PATH = os.path.join(FINAL_RUN_DIR, 'weights', 'best.pt')
DATA_PATH = '/content/Food-Detection-2' # Assuming the data config file is still available

print(f"\nLoading final YOLOv8m model from: {FINAL_WEIGHTS_PATH}")
try:
    model = YOLO(FINAL_WEIGHTS_PATH)
except Exception as e:
    raise FileNotFoundError(f"Error loading model. Ensure the path is correct and the file exists.")

# 2. Run Validation
print("Running final validation to get segmentation accuracy...")
metrics = model.val(data=f'{DATA_PATH}/data.yaml', task='segment', split='val')

# 3. Final Handoff and Metrics
print("\n--- FINAL YOLOv8m SEGMENTATION METRICS ---")
# The mAP@50 is the critical score for pixel accuracy
print(f"Mask mAP@50 (Pixel Accuracy): {metrics.seg.map50:.4f}")
print(f"Mask mAP@50-95 (Overall Accuracy): {metrics.seg.map:.4f}")

# 4. Copy the final model to the clean handoff folder
HANDOFF_DIR = '/content/drive/MyDrive/ML_Food_Project/YOLO_Weights'
print(f"\nCopying FINAL model to Handoff Folder: {HANDOFF_DIR}")
shutil.copy(FINAL_WEIGHTS_PATH, os.path.join(HANDOFF_DIR, 'best_food_seg_model_v75_M.pt')) # Saving with new version name (v75_M)

print("✅ Validation complete. Model saved to Handoff Folder.")

# %%
# --- FINAL SAFE COPY TO DRIVES ---
import shutil
import os

FINAL_RUN_DIR = '/content/drive/MyDrive/YOLO_RESUME_OUTPUT/food_seg_v1_YOLOv8M_CLEAN_START2'
FINAL_WEIGHTS_PATH = os.path.join(FINAL_RUN_DIR, 'weights', 'best.pt')

# Copy the final model to the root of the current account's MyDrive (safe location)
SAFE_DRIVE_COPY = '/content/drive/MyDrive/best_food_seg_model_v75_M_FINAL.pt'
shutil.copy(FINAL_WEIGHTS_PATH, SAFE_DRIVE_COPY)

print(f"\n✅ Model (V75_M) successfully saved to the root of this account's Drive.")
# Out:
# ✅ Model (V75_M) successfully saved to the root of this account's Drive.

# %%
# --- STEP 1: CHECK GPU, LIBRARIES, AND AUTHENTICATE ---
print("Checking for GPU access and installing libraries...")
# !pip install ultralytics roboflow -q

from google.colab import drive
from ultralytics import YOLO
from roboflow import Roboflow
import torch
import os
import time

# 1. GPU Check
if torch.cuda.is_available():
    print(f"✅ GPU is available! Device: {torch.cuda.get_device_name(0)}")
else:
    raise SystemExit("❌ GPU is NOT available. Please stop and try again later.")

# 2. Authenticate Roboflow and Mount Drive
print("\nMounting Google Drive and authenticating Roboflow...")
drive.mount('/content/drive', force_remount=True)

rf = Roboflow(api_key="9PkAjBQJU2ZBQ4GhX9tM")
project = rf.workspace("flens-mikns").project("food-detection-guwga")
version = project.version(2)
print("✅ Authentication and Drive mount complete.")
# Out:
# Checking for GPU access and installing libraries...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 19.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 14.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 84.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 125.6 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ✅ GPU is available! Device: Tesla T4
#
# Mounting Google Drive and authenticating Roboflow...
# Mounted at /content/drive
# ...

# %%
# --- STEP 2: LAUNCH HYPERPARAMETER TEST RUN B (5 EPOCHS, Lower LR) ---

# 1. Re-Download Data (Must be done every session)
print("\nRe-downloading dataset (This is fast)...")
dataset = version.download("yolov8")

# Define all paths
DATA_PATH = '/content/Food-Detection-2'

# 🚨 CORRECT LOAD PATH (Loading the latest saved model from the writeable folder)
DRIVE_RUN_DIR_LATEST = '/content/drive/MyDrive/YOLO_RESUME_OUTPUT/food_seg_v1_YOLOv8M_CLEAN_START2'
CHECKPOINT_PATH = os.path.join(DRIVE_RUN_DIR_LATEST, 'weights', 'last.pt')


# 2. Load the Medium model from the checkpoint
print(f"\nLoading latest medium model from: {CHECKPOINT_PATH} for testing...")
model = YOLO(CHECKPOINT_PATH)


# 3. Launch the test run (5 new epochs only)
print("Starting Hyperparameter Test Run B (5 epochs) with lower learning rate (5e-4)...")

results = model.train(
    data=f'{DATA_PATH}/data.yaml',
    task='segment',
    epochs=5,      # Short run for speed
    imgsz=640,
    batch=16,
    resume=False,  # Start a fresh, small experiment
    name='food_seg_v1_LR_TEST_B',
    project='/content/drive/MyDrive/YOLO_HYPERPARAM_TESTS', # New dedicated folder for tests
    save_period=5,
    # --- CRITICAL HYPERPARAMETER CHANGE ---
    lr0=5e-4 # Setting the initial learning rate to half the default value
)

print("\n🎉 Hyperparameter Test Run B Launched. Check the output in ~25 minutes.")
# Out:
# Re-downloading dataset (This is fast)...
#
# Loading latest medium model from: /content/drive/MyDrive/YOLO_RESUME_OUTPUT/food_seg_v1_YOLOv8M_CLEAN_START2/weights/last.pt for testing...
# Starting Hyperparameter Test Run B (5 epochs) with lower learning rate (5e-4)...
# Ultralytics 8.3.232 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# --- FINAL RESULTS RETRIEVAL (WITH COLUMN NAME FIX) ---
import os
import pandas as pd
from ultralytics import YOLO

# 1. Define Paths (The safe output location)
FINAL_RUN_DIR = '/content/drive/MyDrive/YOLO_HYPERPARAM_TESTS/food_seg_v1_LR_TEST_B'
RESULTS_FILE = os.path.join(FINAL_RUN_DIR, 'results.csv')
FINAL_WEIGHTS_PATH = os.path.join(FINAL_RUN_DIR, 'weights', 'best.pt')
DATA_PATH = '/content/Food-Detection-2'

# 2. Load the CSV file containing the metrics
print(f"Loading results from: {RESULTS_FILE}")
try:
    # Read the CSV, skipping the initial descriptive lines
    df = pd.read_csv(RESULTS_FILE, skipinitialspace=True)
    # The last row contains the final metrics (after the last epoch)
    final_metrics = df.iloc[-1]

except FileNotFoundError:
    print(f"\n❌ ERROR: Results file not found at {RESULTS_FILE}. Ensure the test ran to completion.")
    raise

# 3. Dynamically Find and Extract Metrics
# We search the column names for key phrases like 'seg_loss' and 'mAP50(M)'.
# (M) stands for Mask mAP.
def find_metric(df, partial_name):
    for col in df.columns:
        if partial_name in col:
            return df[col].iloc[-1]
    return None

final_seg_loss = find_metric(df, 'seg_loss')
final_mask_mAP50 = find_metric(df, 'mAP50(M)')

# 4. Run Final Validation (To get a precise final score)
print("Running final validation to confirm Mask mAP...")
model = YOLO(FINAL_WEIGHTS_PATH)
metrics = model.val(data=f'{DATA_PATH}/data.yaml', task='segment', split='val')
final_mask_mAP50_val = metrics.seg.map50

# 5. Print Final Metrics
print("\n--- HYPERPARAMETER TEST B RESULTS ---")
print(f"Final Validation Segmentation Loss (seg_loss): {final_seg_loss:.4f}")
print(f"Final Mask mAP@50 (Accuracy): {final_mask_mAP50_val:.4f}")
print("--------------------------------------")
print(f"Baseline Score (Before Test B): 0.2992")
# Out:
# Loading results from: /content/drive/MyDrive/YOLO_HYPERPARAM_TESTS/food_seg_v1_LR_TEST_B/results.csv
# Running final validation to confirm Mask mAP...
# Ultralytics 8.3.232 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8m-seg summary (fused): 105 layers, 27,359,028 parameters, 0 gradients, 105.0 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1879.3±472.0 MB/s, size: 61.1 KB)
# val: Scanning /content/Food-Detection-2/valid/labels.cache... 1872 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1872/1872 3.5Mit/s 0.0s
# val: /content/Food-Detection-2/valid/images/00000047_resized_jpg.rf.6c5e7ed988d483df9040edd77c150c36.jpg: 1 duplicate labels removed
# val: /content/Food-Detection-2/valid/images/0d7b7f96bf_jpg.rf.1a6f84c82dd14e4f414cc58d10cc8ae1.jpg: 1 duplicate labels removed
# val: /content/Food-Detection-2/valid/images/1013425_jpg.rf.f2db3406a23cee762d0a45cb445e63d9.jpg: 1 duplicate labels removed
# ...

# %%
# --- STEP 3: LAUNCH HYPERPARAMETER TEST RUN C (Strong Augmentation) ---
from ultralytics import YOLO
import os
import time

# Define all paths
DATA_PATH = '/content/Food-Detection-2'
DRIVE_RUN_PATH = '/content/drive/MyDrive/ML_Food_Project/YOLO_Checkpoints/food_seg_v1_YOLOv8M_run_2'
CHECKPOINT_PATH = os.path.join(DRIVE_RUN_PATH, 'weights', 'last.pt')

# 1. Load the Medium model from the checkpoint
print(f"\nLoading medium model from: {CHECKPOINT_PATH} for testing...")
model = YOLO(CHECKPOINT_PATH)

# 2. Launch the test run (5 new epochs only)
print("Starting Hyperparameter Test Run C (5 epochs) with STRONG AUGMENTATION...")

results = model.train(
    data=f'{DATA_PATH}/data.yaml',
    task='segment',
    epochs=5,      # Short run for speed
    imgsz=640,
    batch=16,
    resume=False,  # Start a fresh, small experiment
    name='food_seg_v1_AUG_TEST_C',
    project='/content/drive/MyDrive/YOLO_HYPERPARAM_TESTS', # Saves to the dedicated test folder
    save_period=5,
    # --- CRITICAL HYPERPARAMETER CHANGES (Focus on Data Diversity) ---
    lr0=1e-3,        # Use the default/baseline learning rate
    hsv_h=0.15,      # Increased Hue augmentation
    shear=0.3        # Increased Shear augmentation
)

print("\n🎉 Hyperparameter Test Run C Launched. This run will be critical for final accuracy.")
# Out:
# Loading medium model from: /content/drive/MyDrive/ML_Food_Project/YOLO_Checkpoints/food_seg_v1_YOLOv8M_run_2/weights/last.pt for testing...
# Starting Hyperparameter Test Run C (5 epochs) with STRONG AUGMENTATION...
# Ultralytics 8.3.232 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# --- LOAD AND PRINT FINAL METRICS FOR RUN C ---
import os
import pandas as pd
from ultralytics import YOLO
import time

# Define paths for the finished run
FINAL_RUN_DIR = '/content/drive/MyDrive/YOLO_HYPERPARAM_TESTS/food_seg_v1_AUG_TEST_C'
RESULTS_FILE = os.path.join(FINAL_RUN_DIR, 'results.csv')
FINAL_WEIGHTS_PATH = os.path.join(FINAL_RUN_DIR, 'weights', 'best.pt')
DATA_PATH = '/content/Food-Detection-2'

# 1. Load the CSV file containing the metrics
print(f"Loading results from: {RESULTS_FILE}")
try:
    df = pd.read_csv(RESULTS_FILE, skipinitialspace=True)
    # The last row contains the final metrics (after the last epoch)
    final_metrics = df.iloc[-1]

except FileNotFoundError:
    raise FileNotFoundError(f"\n❌ ERROR: Results file not found at {RESULTS_FILE}.")

# 2. Dynamically Find and Extract Metrics
def find_metric(df, partial_name):
    for col in df.columns:
        if partial_name in col:
            return df[col].iloc[-1]
    return None

final_mask_mAP50 = find_metric(df, 'mAP50(M)')

# 3. Run Final Validation (To get the precise final score)
print("Running final validation to confirm Mask mAP...")
model = YOLO(FINAL_WEIGHTS_PATH)
metrics = model.val(data=f'{DATA_PATH}/data.yaml', task='segment', split='val')
final_mask_mAP50_val = metrics.seg.map50

# 4. Print Final Metrics
print("\n--- HYPERPARAMETER TEST C RESULTS ---")
print(f"Final Mask mAP@50 (Accuracy): {final_mask_mAP50_val:.4f}")
print(f"Baseline Score (Before Test C): 0.2992")
print("--------------------------------------")
# Out:
# Loading results from: /content/drive/MyDrive/YOLO_HYPERPARAM_TESTS/food_seg_v1_AUG_TEST_C/results.csv
# Running final validation to confirm Mask mAP...
# Ultralytics 8.3.232 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8m-seg summary (fused): 105 layers, 27,359,028 parameters, 0 gradients, 105.0 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1276.4±591.7 MB/s, size: 57.7 KB)
# val: Scanning /content/Food-Detection-2/valid/labels.cache... 1872 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1872/1872 3.5Mit/s 0.0s
# val: /content/Food-Detection-2/valid/images/00000047_resized_jpg.rf.6c5e7ed988d483df9040edd77c150c36.jpg: 1 duplicate labels removed
# val: /content/Food-Detection-2/valid/images/0d7b7f96bf_jpg.rf.1a6f84c82dd14e4f414cc58d10cc8ae1.jpg: 1 duplicate labels removed
# val: /content/Food-Detection-2/valid/images/1013425_jpg.rf.f2db3406a23cee762d0a45cb445e63d9.jpg: 1 duplicate labels removed
# ...

# %%
# --- STEP 1: CHECK GPU, LIBRARIES, AND AUTHENTICATE ---
print("Checking for GPU access and installing libraries...")
# !pip install ultralytics roboflow -q

from google.colab import drive
from ultralytics import YOLO
from roboflow import Roboflow
import torch
import os
import time

# 1. GPU Check
if torch.cuda.is_available():
    print(f"✅ GPU is available! Device: {torch.cuda.get_device_name(0)}")
else:
    raise SystemExit("❌ GPU is NOT available. Please stop and try again later.")

# 2. Authenticate Roboflow and Mount Drive
print("\nMounting Google Drive and authenticating Roboflow...")
drive.mount('/content/drive', force_remount=True)

rf = Roboflow(api_key="9PkAjBQJU2ZBQ4GhX9tM")
project = rf.workspace("flens-mikns").project("food-detection-guwga")
version = project.version(2)
print("✅ Authentication and Drive mount complete.")
# Out:
# Checking for GPU access and installing libraries...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 21.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 18.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 37.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 74.2 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ✅ GPU is available! Device: Tesla T4
#
# Mounting Google Drive and authenticating Roboflow...
# Mounted at /content/drive
# ...

# %%
# --- STEP 2: RE-DOWNLOAD DATA AND RESUME TRAINING (Epoch 20 to 50) ---

# 1. Re-Download Data (Must be done every session)
print("\nRe-downloading dataset (This is fast)...")
dataset = version.download("yolov8")

# Define all paths
DATA_PATH = '/content/Food-Detection-2' # Local config path
# 🚨 FINAL CORRECT PATH: Using the verified YOLO_RESUME_OUTPUT path
DRIVE_RUN_PATH = '/content/drive/MyDrive/YOLO_RESUME_OUTPUT/food_seg_v1_YOLOv8M_CLEAN_START2'
CHECKPOINT_PATH = os.path.join(DRIVE_RUN_PATH, 'weights', 'last.pt') # Load the last saved checkpoint

# 2. Resume Training
print(f"\nResuming training from checkpoint: {CHECKPOINT_PATH}. Continuing to Epoch 40...")

# Load the interrupted model from Drive
model = YOLO(CHECKPOINT_PATH)

# The resume=True flag is critical! It tells the system to continue the run from where it left off.
results = model.train(
    data=f'{DATA_PATH}/data.yaml',
    task='segment',
    epochs=40, # The final TARGET: 50
    imgsz=640,
    batch=16,
    resume=True,
    name='food_seg_v1_YOLOv8M_CLEAN_START2_40epochs', # Use the CORRECT run name
    project='/content/drive/MyDrive/YOLO_RESUME_OUTPUT', # SAFE SAVE LOCATION
    save_period=5
)

print("\n🎉 YOLOv8m Segmentation Training RESUMED. Estimated completion: ~3 hours to reach Epoch 50.")
# Out:
# Re-downloading dataset (This is fast)...
# ...
# Extracting Dataset Version Zip to Food-Detection-2 in yolov8:: 100%|██████████| 19506/19506 [00:02<00:00, 6920.85it/s]
# Resuming training from checkpoint: /content/drive/MyDrive/YOLO_RESUME_OUTPUT/food_seg_v1_YOLOv8M_CLEAN_START2/weights/last.pt. Continuing to Epoch 40...
# Ultralytics 8.3.232 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# --- STEP 2: LAUNCH NEW TRAINING RUN (TOTAL 76 EPOCHS) ---

# 1. Re-Download Data (Must be done every session)
print("\nRe-downloading dataset (This is fast)...")
dataset = version.download("yolov8")

# Define all paths
DATA_PATH = '/content/Food-Detection-2'
# Load the best weights from the completed 36-epoch run (the 29% model):
DRIVE_RUN_PATH = '/content/drive/MyDrive/YOLO_RESUME_OUTPUT/food_seg_v1_YOLOv8M_CLEAN_START2'
CHECKPOINT_PATH = os.path.join(DRIVE_RUN_PATH, 'weights', 'best.pt')

# 2. Start Training
print(f"\nLoading 29% accurate model from: {CHECKPOINT_PATH} to continue learning...")

# Load the completed model as the starting point for a NEW run
model = YOLO(CHECKPOINT_PATH)

# Start the NEW training run (no resume=True flag needed, as we start from a finished job)
results = model.train(
    data=f'{DATA_PATH}/data.yaml',
    task='segment',
    epochs=40,
    imgsz=640,
    batch=16,
    name='food_seg_v1_YOLOv8M_40epochs', # NEW RUN NAME
    project='/content/drive/MyDrive/YOLO_RESUME_OUTPUT',
    save_period=5
)

print("\n🎉 YOLOv8m Segmentation Training Initiated. Estimated completion: ~5 hours to reach Epoch 40.")
# Out:
# Re-downloading dataset (This is fast)...
#
# Loading 29% accurate model from: /content/drive/MyDrive/YOLO_RESUME_OUTPUT/food_seg_v1_YOLOv8M_CLEAN_START2/weights/best.pt to continue learning...
# Ultralytics 8.3.232 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# --- STEP 1: CHECK GPU, LIBRARIES, AND AUTHENTICATE ---
print("Checking for GPU access and installing libraries...")
# !pip install ultralytics roboflow -q

from google.colab import drive
from ultralytics import YOLO
from roboflow import Roboflow
import torch
import os
import time

# 1. GPU Check
if torch.cuda.is_available():
    print(f"✅ GPU is available! Device: {torch.cuda.get_device_name(0)}")
else:
    # If the GPU is not back yet, we must wait.
    raise SystemExit("❌ GPU is NOT available. Please stop and try again later.")

# 2. Authenticate Roboflow and Mount Drive
print("\nMounting Google Drive and authenticating Roboflow...")
drive.mount('/content/drive', force_remount=True)

rf = Roboflow(api_key="9PkAjBQJU2ZBQ4GhX9tM")
project = rf.workspace("flens-mikns").project("food-detection-guwga")
version = project.version(2)
print("✅ Authentication and Drive mount complete.")
# Out:
# Checking for GPU access and installing libraries...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 32.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 17.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 64.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 68.2 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ✅ GPU is available! Device: Tesla T4
#
# Mounting Google Drive and authenticating Roboflow...
# Mounted at /content/drive
# ...

# %%
# --- STEP 2: RE-DOWNLOAD DATA AND RESUME TRAINING (Epoch 31 to 40) ---

# 1. Re-Download Data (Must be done every session)
print("\nRe-downloading dataset (This is fast)...")
dataset = version.download("yolov8")

# Define all paths
DATA_PATH = '/content/Food-Detection-2' # Local config path
# The run that was paused:
DRIVE_RUN_PATH = '/content/drive/MyDrive/YOLO_RESUME_OUTPUT/food_seg_v1_YOLOv8M_40epochs'
CHECKPOINT_PATH = os.path.join(DRIVE_RUN_PATH, 'weights', 'last.pt') # Load the last saved checkpoint (Epoch 30)

# 2. Resume Training
print(f"\nResuming training from checkpoint: {CHECKPOINT_PATH}. Continuing to Epoch 40...")

# Load the interrupted model from Drive
model = YOLO(CHECKPOINT_PATH)

# The resume=True flag is critical! It tells the system to continue the run from where it left off.
results = model.train(
    data=f'{DATA_PATH}/data.yaml',
    task='segment',
    epochs=40, # The final TARGET: 40
    imgsz=640,
    batch=16,
    resume=True, # Critical flag to continue from the last completed epoch (Epoch 30)
    name='food_seg_v1_YOLOv8M_40epochs', # Use the SAME run name to continue the existing log
    project='/content/drive/MyDrive/YOLO_RESUME_OUTPUT',
    save_period=5
)

print("\n🎉 YOLOv8m Segmentation Training RESUMED. Estimated completion: ~1 hour to reach Epoch 40.")
# Out:
# Re-downloading dataset (This is fast)...
# ...
# Extracting Dataset Version Zip to Food-Detection-2 in yolov8:: 100%|██████████| 19506/19506 [00:02<00:00, 6573.68it/s]
# Resuming training from checkpoint: /content/drive/MyDrive/YOLO_RESUME_OUTPUT/food_seg_v1_YOLOv8M_40epochs/weights/last.pt. Continuing to Epoch 40...
# Ultralytics 8.3.233 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# --- FINAL VALIDATION AND METRICS CHECK ---
import os
from ultralytics import YOLO
from google.colab import drive
import torch
import time

# 1. Check/Mount Drive (Necessary to access the final model weights)
print("Checking Drive mount...")
if not os.path.exists('/content/drive/MyDrive'):
    drive.mount('/content/drive', force_remount=True)

# 2. Define Paths and Load Model
# The model was saved to this NEW, writeable location:
FINAL_RUN_DIR = '/content/drive/MyDrive/YOLO_RESUME_OUTPUT/food_seg_v1_YOLOv8M_40epochs'
FINAL_WEIGHTS_PATH = os.path.join(FINAL_RUN_DIR, 'weights', 'best.pt')
DATA_PATH = '/content/Food-Detection-2' # Assuming the data config file is still available


# 3. Load the fully trained model
print(f"\nLoading final YOLOv8m model from: {FINAL_WEIGHTS_PATH}")
try:
    model = YOLO(FINAL_WEIGHTS_PATH)
except Exception as e:
    print(f"❌ ERROR: Could not load model. Ensure the training job completed and saved the 'best.pt' file.")
    raise

# 4. Run Validation
print("Running final validation to get segmentation accuracy...")
metrics = model.val(data=f'{DATA_PATH}/data.yaml', task='segment', split='val')

# 5. Print Final Metrics
print("\n--- FINAL YOLOv8m SEGMENTATION METRICS (40 Epochs Total) ---")
print(f"Mask mAP@50 (Pixel Accuracy): {metrics.seg.map50:.4f}")
print(f"Mask mAP@50-95 (Overall Accuracy): {metrics.seg.map:.4f}")
# Out:
# Checking Drive mount...
#
# Loading final YOLOv8m model from: /content/drive/MyDrive/YOLO_RESUME_OUTPUT/food_seg_v1_YOLOv8M_40epochs/weights/best.pt
# Running final validation to get segmentation accuracy...
# Ultralytics 8.3.233 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8m-seg summary (fused): 105 layers, 27,359,028 parameters, 0 gradients, 105.0 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1371.7±432.6 MB/s, size: 61.1 KB)
# val: Scanning /content/Food-Detection-2/valid/labels.cache... 1872 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1872/1872 695.4Kit/s 0.0s
# val: /content/Food-Detection-2/valid/images/00000047_resized_jpg.rf.6c5e7ed988d483df9040edd77c150c36.jpg: 1 duplicate labels removed
# val: /content/Food-Detection-2/valid/images/0d7b7f96bf_jpg.rf.1a6f84c82dd14e4f414cc58d10cc8ae1.jpg: 1 duplicate labels removed
# ...

# %%
# --- FINAL VALIDATION AND METRICS CHECK ---
import os
from ultralytics import YOLO
from google.colab import drive
import torch
import time

# 1. Ensure Drive Mount (Necessary to access the final model weights)
print("Checking Drive mount...")
if not os.path.exists('/content/drive/MyDrive'):
    drive.mount('/content/drive', force_remount=True)

# 2. Define Paths and Load Model
# The model was saved to this NEW, clean location to bypass permission errors:
FINAL_RUN_DIR = '/content/drive/MyDrive/YOLO_RESUME_OUTPUT/food_seg_v1_YOLOv8M_CLEAN_START2'
FINAL_WEIGHTS_PATH = os.path.join(FINAL_RUN_DIR, 'weights', 'best.pt')
DATA_PATH = '/content/Food-Detection-2' # Assuming the data config file is still available


print(f"\nLoading final YOLOv8m model from: {FINAL_WEIGHTS_PATH}")
try:
    model = YOLO(FINAL_WEIGHTS_PATH)
except Exception as e:
    # This might fail if the file wasn't written to the correct folder
    raise FileNotFoundError(f"Error loading model. Ensure the training run completed and saved to the '{FINAL_RUN_DIR}' folder.")

# 3. Run Validation
print("Running final validation to get segmentation accuracy...")
metrics = model.val(data=f'{DATA_PATH}/data.yaml', task='segment', split='val')

# 4. Print Final Metrics
print("\n--- FINAL YOLOv8m SEGMENTATION METRICS ---")
print(f"Mask mAP@50 (Pixel Accuracy): {metrics.seg.map50:.4f}")
print(f"Mask mAP@50-95 (Overall Accuracy): {metrics.seg.map:.4f}")
# Out:
# Checking Drive mount...
#
# Loading final YOLOv8m model from: /content/drive/MyDrive/YOLO_RESUME_OUTPUT/food_seg_v1_YOLOv8M_CLEAN_START2/weights/best.pt
# Running final validation to get segmentation accuracy...
# Ultralytics 8.3.233 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8m-seg summary (fused): 105 layers, 27,359,028 parameters, 0 gradients, 105.0 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1947.0±617.2 MB/s, size: 58.1 KB)
# val: Scanning /content/Food-Detection-2/valid/labels.cache... 1872 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1872/1872 3.3Mit/s 0.0s
# val: /content/Food-Detection-2/valid/images/00000047_resized_jpg.rf.6c5e7ed988d483df9040edd77c150c36.jpg: 1 duplicate labels removed
# val: /content/Food-Detection-2/valid/images/0d7b7f96bf_jpg.rf.1a6f84c82dd14e4f414cc58d10cc8ae1.jpg: 1 duplicate labels removed
# ...
